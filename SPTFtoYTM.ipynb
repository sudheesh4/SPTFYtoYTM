# %%
import regex as re
import time
import pywhatkit
from datetime import datetime

from selenium import webdriver

from simon.accounts.pages import LoginPage
from simon.header.pages import HeaderPage
from simon.pages import BasePage

import time

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select, WebDriverWait


from selenium.webdriver.common.action_chains import ActionChains

# %%
driver = webdriver.Firefox()
driver.get("https://spotify.com")

# %%
listed=driver.find_elements(By.TAG_NAME,'li')

# %%
#print(listed[2])

# %%
rowi = '//*[@role="row"]'
rowp = driver.find_elements(By.XPATH,rowi)

# %%
#print(rowp[0].get_attribute('innerHTML'))


col = '//*[@data-testid="tracklist-row"]'
song=rowp[0].find_elements(By.XPATH,col)
#print(song[5].get_attribute('innerHTML'))

#data-testid="internal-track-link"
snam = '//*[@data-testid="internal-track-link"]'
for i in range(len(song)):
    "SA"
    #print(f">>>>>>>>>{i}")
    #print(song[i].find_element(By.XPATH,snam).find_element(By.TAG_NAME,'div').get_attribute('innerHTML'))

# %%
container=driver.find_element(By.CLASS_NAME,'main-view-container')

#data-testid="track-list"
table=container.find_elements(By.XPATH,'//*[@data-testid="track-list"]')
#print(table.find_elements(By.TAG_NAME,'a')[10].get_attribute('innerHTML'))#data-testid="internal-track-link"
#class="main-view-container"
NAME=[]
print(len(table))
for row in table:
    
    rows=row.find_elements(By.XPATH,'//*[@role="row"]')
    
    print(len(rows))
    #data-testid="tracklist-row"
    for c in rows:
        
        
        divs=(c.find_elements(By.TAG_NAME,'div'))#.get_attribute('aria-colindex'))
        nm=''
        for  d in divs:
            temp=d.get_attribute('aria-colindex')
            if temp and int(temp)==2:
                try:
                    aa=d.find_element(By.TAG_NAME,'a')
                    nm=nm+str(aa.find_element(By.TAG_NAME,'div').get_attribute('innerHTML'))
                except:
                    pass
            "asas"
            if temp and int(temp)==3:
                try:
                    aa=d.find_element(By.TAG_NAME,'a')
                    #print(f">>>>{str(aa.get_attribute('innerHTML'))}")
                    nm=nm+">>>"+str(aa.get_attribute('innerHTML'))
                except:
                    pass
                #print(temp)
        #print(nm)
        NAMES.append(nm)
        row.send_keys(Keys.DOWN)
        #aria-colindex="2"
        #print(c.find_elelments(By.XPATH,'[@data-testid="tracklist-row"]'))#.get_attribute('aria-rowindex'))#.find_element(By.TAG_NAME,'a'))#.find_element(By.TAG_NAME,'div').get_attribute('innerHTML'))
# Out:
# 1
# 30

# %%
import copy
def getnames(driver):
    NAMES=[]
    container=driver.find_element(By.CLASS_NAME,'main-view-container')

    #data-testid="track-list"
    table=container.find_elements(By.XPATH,'//*[@data-testid="track-list"]')
    #print(table.find_elements(By.TAG_NAME,'a')[10].get_attribute('innerHTML'))#data-testid="internal-track-link"
    #class="main-view-container"

    #print(len(table))
    count=0
    table=container.find_elements(By.XPATH,'//*[@data-testid="track-list"]')
    itera=iter(table)
    while count<100:
        try:
            row=next(itera)
        except:
            break
        rows=row.find_elements(By.XPATH,'//*[@role="row"]')

        #print(len(rows))
        #data-testid="tracklist-row"
        for c in rows:


            divs=(c.find_elements(By.TAG_NAME,'div'))#.get_attribute('aria-colindex'))
            nm=''
            for  d in divs:
                temp=d.get_attribute('aria-colindex')
                if temp and int(temp)==2:
                    #print('aaa')
                    try:
                        aa=d.find_element(By.TAG_NAME,'a')
                        nm=nm+str(aa.find_element(By.TAG_NAME,'div').get_attribute('innerHTML'))+">>>"+d.find_element(By.TAG_NAME,'span').find_element(By.TAG_NAME,'a').get_attribute('innerHTML')
                        
                    except:
                        pass
                "asas"
                if temp and int(temp)==3:
                    #print('bb')
                    try:
                        aa=d.find_element(By.TAG_NAME,'a')
                        #print(f">>>>{str(aa.get_attribute('innerHTML'))}")
                        nm=nm+">>>"+str(aa.get_attribute('innerHTML'))
                    except:
                        pass
                    #print(temp)
            #print(nm)
            NAMES.append(nm)
            #row.send_keys(Keys.DOWN)
            count=count+1
    
    itera=next(iter(table))
    for i in range(count):
        #print(i)
        itera.send_keys(Keys.DOWN)
    return copy.deepcopy(NAMES)

# %%
c=0
na=[]
while not True:
    #temp=getnames(driver)
    #na.extend(temp)
    #print(c)
    "c=c+99"

# %%
NAMELIST=list(set(copy.deepcopy(na)))

# %%
#len(list(set(NAMELIST)))

# %%
NAMELIST[13].split('>>>')#(song,artist,album)
# Out:
# ['Chasing Birds - Preservation Hall Jazz Band Re-Version',
#  'Foo Fighters',
#  'Chasing Birds (Preservation Hall Jazz Band Re-Version)']

# %%
import numpy as np
#np.save('SPT_DATA.npy',NAMELIST,allow_pickle=True)
NAMELIST=np.load('SPT_DATA.npy',allow_pickle=True)

# %%
urllist=np.load('YTM_DATA.npy',allow_pickle=True)

# %%
#!pip3  install googleapiclient
#np.save??
import os

# %%
#GOOGLE API: AIzaSyDyHFMQt_Eo_xqI3RzKL2hmupLpSjeYus0


#GOOGLE OAUTH:
#clientid: 233031269683-7plg1b5sl1l7n9t7dej43m7bt1sbhdp8.apps.googleusercontent.com
#clientsecret: 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

# %%
#!pip3 install --upgrade google-api-python-client
#!pip3 install google_auth_oauthlib

# %%
#YT SEARCH PIPELINE
from googleapiclient.discovery import build
#from credentials import yt_api

import json
import time



def makePublicService(api_key):
    service = build(serviceName='youtube',version='v3',developerKey=api_key)
    
    return service


def getVideoIds(queries,api):
    service = makePublicService(api)
    ids = []
    for i in range(len(queries)):
        request = service.search().list(part="snippet",
                maxResults=2,
                q = queries[i]
            )
        response = request.execute()
        videoid = response['items'][0]['id']['videoId']
        #print(videoid)

        ids.append(videoid)
        time.sleep(1)
    return ids


api="APIKEY"
test='Run'
art='BTS'
alb='Proof'
queries=[f"Song: {test} ; Artist: {art} ;Album: {alb}"]
#print(getVideoIds(queries,api))

# %%
len(NAMELIST)#,len(urllist)
# Out:
# 1094

# %%
#YT PLAYLIST PIPELINE
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow


def makeService():
    credentials = None
    flow = InstalledAppFlow.from_client_secrets_file(
        "client_secret.json",
        scopes=["https://www.googleapis.com/auth/youtube"],
    )
    flow.run_local_server(
        port=8080, prompt="consent", authorization_prompt_message=""
    )
    credentials = flow.credentials
    service = build(serviceName="youtube", version="v3", credentials=credentials)
    print('serve')
    return service


def makePlaylist(serv, name):
    request = serv.playlists().insert(
        part="snippet", body={"snippet": {"title":str(name)}}
    )
    
    response = request.execute()
    print('playlist')
    return response['id']


def addItemToPlaylist(service, pl_id, items):
    res = []
    for i in items:
        request = service.playlistItems().insert(
            part="snippet",
            body={
                "snippet": {
                    "playlistId": str(pl_id),
                    "resourceId": {"kind": "youtube#video", "videoId": i},
                }
            },
        )
        response = request.execute()
        print("Added")
        res.append(response)

    return res

serv=makeService()
plid=makePlaylist(serv,"HelloWorld!")
#addItemToPlaylist(serv,plid,['a4YwJCZRh5M'])

# %%
time.sleep(2)
driver.quit()

# %%
import os
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request


flow=InstalledAppFlow.from_client_secrets_file("client_secrets.json",
                                               scopes=["https://www.googleapis.com/auth/youtube.readonly"])
flow.run_local_server(port=8080,prompt="consent",authorization_prompt_message="")
creds=flow.credentials
print(creds.to_json())
# Out:
# {"token": "ya29.a0AfB_byAV72EJ9lIcGEPxnrhONfniaqpolnxnX-39d6mzq4LS_Jnp8zPMjByKAWp-Cqw5Z5aUOxjJAXcjAM-PRQ8iMF7mNcEXcUamRGqf8y9ZOMogHkpKbI9h-eiZj_9Nv5pkaHZeF8auHR49DrNWq5E91DIqvWg-NwL6aCgYKAeYSARMSFQHGX2Mi7nKEjWLvGeCXQW49jUEaYQ0171", "refresh_token": "1//05KHlKged1oEPCgYIARAAGAUSNwF-L9IrY6yxZDJ-uBgyaVEcscf4VlNaHkAhJ4ZJT3iwD_PqHtslTz0QUM54to9JUrlW-WQ2Pj0", "token_uri": "https://oauth2.googleapis.com/token", "client_id": "865785232618-ek10k6i9f110lr6a42085ckambao67p7.apps.googleusercontent.com", "client_secret": "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", "scopes": ["https://www.googleapis.com/auth/youtube.readonly"], "expiry": "2023-11-20T00:54:49.078299Z"}

# %%
#####################################################################

# %%
video_ids=[]

# %%
api_key="APIKEY"

# %%
#from selenium.webdriver.firefox.options import Options
from selenium.webdriver.chrome.options import Options 
def mygetvideo(query):
    op = webdriver.ChromeOptions()
    op.add_argument('headless')
    ydrv = webdriver.Chrome(options=op)
    #ydrv=webdriver.Firefox(options=options)
    #ydrv=webdriver.Chrome(options=options)
    ydrv.get("https://www.youtube.com/results?search_query="+str(query))
    time.sleep(2)
    sresults=ydrv.find_elements(By.TAG_NAME,'ytd-two-column-search-results-renderer')[0].find_elements(By.TAG_NAME,'ytd-item-section-renderer')
    val=''
    for res in sresults:
        try:
            svid=res.find_elements(By.TAG_NAME,'ytd-video-renderer')
            sng=svid[0].find_element(By.TAG_NAME,'ytd-thumbnail').find_element(By.TAG_NAME,'a')
            val=sng.get_attribute('href').split('&')[0].split('?')[1][2:]
            break
        except:
            continue
    ydrv.quit()
    return val

# %%
1

# %%
mygetvideo(query)
# Out:
# '1poXN3jF3Bw'

# %%
file1 = open('urlfile.txt', 'r',encoding='UTF-8')
Lines = file1.readlines()
count=0
stind=0
newvid_ids=[]
for l in Lines:
    if l[0]=='#':
        newvid_ids.append(l[3:-1])
        #print(l[3:])
        count=count+1
print(Lines[-2])
for i in range(len(NAMELIST)):
    if len(NAMELIST[i].split(">>>"))<3:
        
        continue
    song,art,alb=NAMELIST[i].split(">>>")
    queries=[f"Song: {song} ; Artist: {art} ;Album: {alb}"]
    #print(Lines[-2]queries[0])
    if Lines[-2]==queries[0]:
        print("HEER")
        stind=i
        break
        
print(count)
#print(Lines[-2])
# Out:
# Song: Distant Dreamer ; Artist: Duffy ;Album: Rockferry
#
# 90

# %%
#newvid_ids

# %%
urllist=[]

tot=0
counter=0
for i in range(91,len(NAMELIST)):
    if len(NAMELIST[i].split(">>>")) < 3 :
        continue
    else:
        song,art,alb=NAMELIST[i].split(">>>")
        queries=[f"Song: {song} ; Artist: {art} ;Album: {alb}"]
        try:
            #vid=getVideoIds(queries,api_key)
            print(queries[0])
            vid=mygetvideo(queries[0])
            #video_ids.append(vid[0])
            #newvid_ids.append(vid)
            #print(vid[0])
            print('###'+str(vid))
            tot=tot+1
            if tot<=90:
                urllist.append((queries[0],vid))
                video_ids.append(vid)
            else:
                np.save('YTM_DATA_'+str(counter)+'.npy',urllist,allow_pickle=True)
                print(f"saved{counter}")
                counter=counter+1
                urllist=[]
                tot=0
                
                
        except:
            print('EEE')
            continue
# Out:
# Song: Scars Leave Beautiful Trace ; Artist: Car, the garden ;Album: Alchemy of Souls (Original Television Soundtrack)
# ###dGoHLoDmHdI
# Song: Mein Koun Houn ; Artist: Mooroo ;Album: Mein Koun Houn
# ###UvyC738fD4o
# Song: Love Yourself ; Artist: Justin Bieber ;Album: Purpose (Deluxe)
# ###oyEuk8j8imI
# Song: Dil Beparvah - The Dewarists, Season 5 ; Artist: Ankur Tewari ;Album: Dil Beparvah (The Dewarists, Season 5)
# ###2N8_XDPW67Q
# Song: A thought on an autumn night ; Artist: JANNABI ;Album: JANNABI's Small Pieces l
# ###Ai5vlozTFNU
# Song: In front of city hall at the subway station ; Artist: Kwak Jin Eon ;Album: HOSPITAL PLAYLIST (Original Television Soundtrack), Pt. 6
# ###OD7JTf7QOVY
# Song: Jutti Meri ; Artist: Neha Bhasin ;Album: Folktales Live Season 1
# ###XV--2ysknlk
# Song: Choo Lo ; Artist: The Local Train ;Album: Aalas Ka Pedh
# ###sFMRqxCexDk
# Song: Ranjish Hi Sahi ; Artist: Ali Sethi ;Album: Coke Studio Season 10: Episode 1
# ###pba_YmWDAIU
# ...

# %%
#np.save('YTM_DATA.npy',urllist,allow_pickle=True)
#print("SAVED! YTM_DATA.npy (query,url)")

# %%
#op = webdriver.ChromeOptions()
#op.add_argument('headless')
#ydrv = webdriver.Firefox()
#ydrv=webdriver.Firefox(options=options)
#ydrv=webdriver.Chrome(options=options)
#ydrv.get("https://www.youtube.com/")

# %%
ydrv.quit()

# %%
test='Run'
art='BTS'
alb='Proof'
queries=[f"Song: {test} ; Artist: {art} ;Album: {alb}"]
print(getVideoIds(queries,api))

# %%
#urllist=np.load('YTM_DATA.npy',allow_pickle=True)
video_ids=[]
for i in range(8):
    urllist=np.load('YTM_DATA_'+str(i)+'.npy',allow_pickle=True)
    
    for u in urllist:
        video_ids.append(u[1])
video_ids=list(set(video_ids))
    #print("%%%%%%%%%%")

# %%
##########################################################

# %%
import os
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import pickle
def makeService():
    credentials = None
    # token.pickle stores the user's credentials from previously successful logins
    if os.path.exists("token.pickle"):
        print("Loading Credentials From File...")
        with open("token.pickle", "rb") as token:
            credentials = pickle.load(token)

    # If there are no valid credentials available, then either refresh the token or log in.
    if not credentials or not credentials.valid:
        if credentials and credentials.expired and credentials.refresh_token:
            print("Refreshing Access Token...")
            credentials.refresh(Request())
        else:
            print("Fetching New Tokens...")
            flow = InstalledAppFlow.from_client_secrets_file(
                "client_secrets.json",
                scopes=["https://www.googleapis.com/auth/youtube"],
            )

            flow.run_local_server(
                port=8080, prompt="consent", authorization_prompt_message=""
            )
            credentials = flow.credentials

            # Save the credentials for the next run
            with open("token.pickle", "wb") as f:
                print("Saving Credentials for Future Use...")
                pickle.dump(credentials, f)

    service = build(serviceName="youtube", version="v3", credentials=credentials)

    return service


def makePlaylist(serv, name):
    request = serv.playlists().insert(
        part="snippet", body={"snippet": {"title":str(name)}}
    )
    
    response = request.execute()
    return response['id']


#test_pl_id = 'PLZ_InQ-iKUHOM2w4K-5OyER_gYul7F-2s'
#video_ids = ['oyLVu753XJw', 'rQeUwx7IKFo', '13z2kF6TiCc', 'jAUSF4_ygJg', 'BlHjfL0pcsw', 'utmSky40VCc', '1xYZeDReUz4', 'Y7G-tYRzwYY', '6ZnnjW6Jj1g', '82eGj8wpzoo', 'dv_Qjzca56k', '0KozfDYK1EU', 'Sjh1PQ9B73Y', 'vcH5RCEzyD0']


def addItemToPlaylist(service, pl_id, items):
    res = []
    for i in items:
        try:
            request = service.playlistItems().insert(
                part="snippet",
                body={
                    "snippet": {
                        "playlistId": str(pl_id),
                        "resourceId": {"kind": "youtube#video", "videoId": i},
                    }
                },
            )
            response = request.execute()
            print("Added")
            res.append(response)
        except:
            continue

    return res

serv=makeService()
test_pl_id=makePlaylist(serv,"Pseudo-Spoti!")
addItemToPlaylist(serv,test_pl_id,video_ids)
# Out:
# Loading Credentials From File...
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# Added
# ...

# %%
print("DONE!")
# Out:
# DONE!
